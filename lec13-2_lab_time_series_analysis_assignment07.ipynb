# %% [markdown]
# ## 기초데이터과학 (01분반)
#
# ## Programming assignment 07

# %% [markdown]
# ### 1.NYC 온도 데이터 Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 URL
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/daily-min-temperatures.csv"

# 데이터 불러오기
data = pd.read_csv(url, parse_dates=["Date"])

# 데이터 확인
data.head(5)
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %% [markdown]
# #### 1-1. 온도 변화를 확인할 수 있도록 선 그래프를 출력하세요.

# %%
# 선 그래프 그리기

sns.lineplot(data,x = data['Date'],y=data['Temp'])
plt.ylabel('Temperature')
plt.title('NYC Daily Minimum Temperatures')
# Out:
# Text(0.5, 1.0, 'NYC Daily Minimum Temperatures')

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 1-2. 데이터셋의 가장 오래된 일과 가장 최신 일 간격을 계산하세요.

# %%
# 데이터셋의 기록된 시작 날과 끝나는 날 간격 계산

oldest_day = data['Date'].min()
recent_day = data['Date'].max()

term = recent_day - oldest_day
# 결과 출력
print("Start Date:",oldest_day,", End Date:",recent_day, ",Duration:",term.days)
# Out:
# Start Date: 1981-01-01 00:00:00 , End Date: 1990-12-31 00:00:00 ,Duration: 3651

# %% [raw]
# Start Date: 1981-01-01 00:00:00, End Date: 1990-12-31 00:00:00, Duration: 3651 days

# %% [markdown]
# #### 1-3. '1985'년 데이터만 추출해서 그래프를 출력하세요.

# %%
# 'Date' 속성을 인덱스로 설정

data2 = data.copy()

data3 = data2.copy()
data3['Year'] = data2['Date'].dt.year

# data3
data2 = data2.set_index('Date')


# '1985' 데이터만 추출하여 변수에 저장
# data2.query('Date == 1985')

data4 = data3.query('Year == 1985')

# 선 그래프 출력
sns.lineplot(data4,x = data4['Date'], y = data4['Temp'])
plt.title('NYC Temperatures in 1985')
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 1-4. 데이터셋을 월 주기(매월 말일)로 다운샘플링하여 그래프를 출력하세요.

# %%
# 매월 말일 기준으로 평균값으로 다운샘플링

down = data2.resample('ME').mean()
# 선 그래프 출력
# down

sns.lineplot(down)
plt.title('Monthly Average Temperature')
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ### 2. Our World in Data COVID-19 Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
url = "https://covid.ourworldindata.org/data/owid-covid-data.csv"
data = pd.read_csv(url, parse_dates=["date"])

# 한국 데이터만 저장 (location 컬럼 값이 South Korea인 행만 추출)
country_data = data[data['location'] == 'South Korea']

country_data.head(5)
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 359238      KOR      Asia  South Korea 2020-01-05          0.0        0.0
# 359239      KOR      Asia  South Korea 2020-01-06          0.0        0.0
# 359240      KOR      Asia  South Korea 2020-01-07          0.0        0.0
# 359241      KOR      Asia  South Korea 2020-01-08          0.0        0.0
# 359242      KOR      Asia  South Korea 2020-01-09          0.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 359238                 NaN           0.0         0.0                  NaN
# 359239                 NaN           0.0         0.0                  NaN
# 359240                 NaN           0.0         0.0                  NaN
# 359241                 NaN           0.0         0.0                  NaN
# 359242                 NaN           0.0         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 359238  ...          40.9                     NaN                       12.27
# 359239  ...          40.9                     NaN                       12.27
# 359240  ...          40.9                     NaN                       12.27
# 359241  ...          40.9                     NaN                       12.27
# 359242  ...          40.9                     NaN                       12.27
#
#         life_expectancy  human_development_index  population  \
# 359238            83.03                    0.916    51815808
# 359239            83.03                    0.916    51815808
# 359240            83.03                    0.916    51815808
# 359241            83.03                    0.916    51815808
# 359242            83.03                    0.916    51815808
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 359238                                  24.4                         0.38
# 359239                                   NaN                          NaN
# 359240                                   NaN                          NaN
# 359241                                   NaN                          NaN
# 359242                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 359238              0.38                                 0.470636
# 359239               NaN                                      NaN
# 359240               NaN                                      NaN
# 359241               NaN                                      NaN
# 359242               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# #### 2-1. 한국의 날짜별 신규 확진자 그래프를 그리세요.

# %%
# 데이터셋의 'new_cases' (신규 확진자) 그래프 그리기

# sns.barplot(country_data,x = country_data['date'],y = country_data['new_cases']) #그래프 개형이 이상함
sns.barplot(country_data,x = country_data['date'],y = country_data['new_cases_smoothed'])
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.title('Daily New Cases in South Korea')
# Out:
# Text(0.5, 1.0, 'Daily New Cases in South Korea')

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 2-2. 코로나 발병 365일부터 730일 사이 신규확진자 수를 계산하세요.

# %%
# 기준일로부터 각 date 컬럼 값 차이를 계산하여 ref_date 컬럼으로 저장
country_data = country_data.copy()
country_data.loc[:,'ref_date'] = (country_data['date'] - country_data['date'].min()).dt.days
# country_data
# 'ref_date' 컬럼을 인덱스로 설정
country_data.set_index('ref_date', inplace=True)

# '365 day'부터 '730 day'까지 신규 확진자 수의 합계 계산
cases_sum = country_data.loc[365:730,'new_cases'].sum()

# 결과 출력
print("Total cases from 365 day to 730 day :",cases_sum)
# Out:
# Total cases from 365 day to 730 day : 577951.0

# %% [raw]
# Total cases from 365 day to 730 day : 577951.0

# %% [markdown]
# #### 2-3. 2022년 3월 신규 확진자 수를 그래프로 출력하세요.

# %%
# date 컬럼을 인덱스로 설정하고 '2022-03' 데이터 추출

country_data.set_index('date', inplace=True)
data_22_03 = country_data.loc['2022-03']
# 그래프 출력
sns.lineplot(data_22_03,x=data_22_03.index,y=data_22_03['new_cases'])
# Out:
# <Axes: xlabel='date', ylabel='new_cases'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 2-4. 데이터셋을 주별 신규 확진자 합계로 다운샘플링하여 그래프를 출력하세요.

# %%
# 리샘플링 (주별 신규 확진자 합계)
weekly_data = country_data['new_cases'].resample('W').sum()

weekly_data
# 그래프 출력
sns.lineplot(x=weekly_data.index,y=weekly_data.values)
# Out:
# <Axes: xlabel='date'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ### 3. Bitcoin Historical Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
url = "https://www.cryptodatadownload.com/cdd/Binance_BTCUSDT_d.csv"
data = pd.read_csv(url, skiprows=1, parse_dates=["Date"])

data.head(5)
# Out:
#             Unix       Date   Symbol      Open      High       Low     Close  \
# 0  1732752000000 2024-11-28  BTCUSDT  95863.11  96564.00  94640.00  95643.98
# 1  1732665600000 2024-11-27  BTCUSDT  91965.16  97208.21  91792.14  95863.11
# 2  1732579200000 2024-11-26  BTCUSDT  93010.01  94973.37  90791.10  91965.16
# 3  1732492800000 2024-11-25  BTCUSDT  97900.05  98871.80  92600.19  93010.01
# 4  1732406400000 2024-11-24  BTCUSDT  97672.40  98564.00  95734.77  97900.04
#
#     Volume BTC   Volume USDT  tradecount
# 0  28814.54357  2.749862e+09     4988161
# 1  41153.42734  3.894359e+09     6648690
# 2  57858.73138  5.370919e+09    10225809
# 3  50847.45096  4.883445e+09     8289691
# 4  31200.97838  3.034172e+09     4964720

# %% [markdown]
# #### 3-1. 비트 코인의 일별 종가 그래프를 그리세요.

# %%
# 데이터셋의 'Close' (일별 종가) 속성 그래프 그리기
sns.lineplot(data,x=data['Date'],y=data['Close'])
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 3-2. 비트 코인 데이터셋에서 가장 높은 종가가 발생한 날짜를 출력하세요.

# %%
# 가장 높은 종가가 발생한 날짜 찾기
highest_day = data.loc[data['Close'] == data['Close'].max(),'Date']

# 결과 출력
highest_day
# Out:
# 6   2024-11-22
# Name: Date, dtype: datetime64[ns]

# %% [raw]
# Highest Close Price Date: 2024-11-22 00:00:00

# %% [markdown]
# #### 3-3. 2022년의 일별 종가 그래프를 출력하세요.

# %%
# 시간 인덱스를 'Date'로 설정하고 '2022' 추출
data.set_index('Date', inplace=True)
data_22 = data.loc['2022']

# 2022년의 'Close' (일별 종가) 그래프 출력
sns.lineplot(data_22,x=data_22.index,y=data_22['Close'])
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 3-4. 데이터셋을 월 주기(매월 1일)로 다운샘플링하여 그래프를 출력하세요.

# %%
# 매월 1일 기준으로 평균값으로 다운샘플링
data_monthly = data['Close'].resample('MS').mean()

# data_monthly를 DataFrame으로 변환
data_monthly = data_monthly.to_frame(name='Close') # 'Close' 열로 DataFrame 생성

# 그래프 출력
sns.lineplot(data=data_monthly, x=data_monthly.index, y='Close') # y는 열 이름으로 지정
# Out:
# <Axes: xlabel='Date', ylabel='Close'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ### 4. European Central Bank Exchange Rate Dataset로 각 문제에 맞게 코드를 작성하세요.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터 로드
url = "https://www.ecb.europa.eu/stats/eurofxref/eurofxref-hist.csv"
data = pd.read_csv(url)

# data = pd.read_csv("eurofxref-hist.csv")

data.head(5)
# Out:
#          Date     USD     JPY     BGN  CYP     CZK     DKK      EEK      GBP  \
# 0  2010-02-14  2.0000    1.00  2.0000  NaN   1.000  2.0000   1.0000   2.0000
# 1  2010-02-12  5.0000    6.00  7.0000  NaN   8.000  9.0000  10.0000  11.0000
# 2  2010-02-10  1.3740  123.01  1.9558  NaN  26.108  7.4449  15.6466   0.8798
# 3  2010-02-09  1.3760  123.40  1.9558  NaN  26.099  7.4448  15.6466   0.8804
# 4  2010-02-08  1.3675  122.07  1.9558  NaN  26.168  7.4442  15.6466   0.8761
#
#       HUF  ...       IDR     INR      KRW      MXN      MYR      NZD     PHP  \
# 0    1.00  ...      1.50   1.600     1.70   1.8000   1.9000   2.1000   2.200
# 1   12.00  ...     28.00  29.000    30.00  31.0000  32.0000  33.0000  34.000
# 2  271.55  ...  12871.34  63.884  1591.64  17.9438   4.7149   1.9827  63.800
# 3  272.00  ...  12878.09  64.197  1601.45  18.0645   4.7235   1.9877  63.836
# 4  273.90  ...  12861.76  64.013  1602.60  18.0130   4.7063   1.9914  63.705
#
#        SGD     THB      ZAR
# 0   2.3000   2.400   2.5000
# 1  35.0000  36.000  37.0000
# 2   1.9483  45.576  10.5998
# 3   1.9511  45.649  10.5992
# 4   1.9450  45.387  10.6097
#
# [5 rows x 41 columns]

# %% [markdown]
# #### 4-1. 유로 달러 환율 그래프를 출력하세요.

# %%
# 'USD' (달러) 속성에 대한 그래프 출력
sns.lineplot(data,x=data['Date'],y=data['USD'])
# Out:
# <Axes: xlabel='Date', ylabel='USD'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 4-2. 환율 데이터의 가장 오래된 날짜와 최신 날짜를 출력하고, 두 날짜 간의 시간 간격(일 수)을 계산하세요.

# %%
# 'Date' 속성을 datetime 객체로 변환
data['Date'] = pd.to_datetime(data['Date'])

# 데이터셋의 기록된 시작 날과 끝나는 날 간격 계산
min_date = data['Date'].min()
max_date = data['Date'].max()
time_interval = (max_date - min_date).days


# 결과 출력
print("Start Date:",min_date,", End Date:",max_date, ",Duration:",time_interval)
# Out:
# Start Date: 1999-01-05 00:00:00 , End Date: 2010-02-14 00:00:00 ,Duration: 4058

# %% [raw]
# Start Date: 1999-01-05 00:00:00, End Date: 2010-02-14 00:00:00, Duration: 4058 days

# %% [markdown]
# #### 4-3. 2010년 1월의 엔화 데이터를 그래프로 출력하세요.

# %%
# Date 컬럼을 인덱스로 설정
data.set_index('Date', inplace=True)

# 2010년 1월 데이터 추출
data = data.sort_index()
data_10_01 = data.loc['2010-01-01':'2020-01-31']

data_10_01

# 'JPY' 속성에 대한 그래프 출력
sns.lineplot(data_10_01,x=data_10_01.index,y=data_10_01['JPY'])
# Out:
# <Axes: xlabel='Date', ylabel='JPY'>

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# #### 4-4. USD 컬럼의 데이터를 시간 단위로 업샘플링하고, 보간법(interpolation)을 사용하여 결측값을 채운 데이터를 그래프를 그려 시각화하세요.

# %%
# 'USD' 속성에 대해 업샘플링 (시간 단위) 및 'polynomial' (다항식 보간법) 적용 (order=2)
data_upsampled = data['USD'].resample('H').mean()
data_upsampled = data_upsampled.interpolate(method='polynomial', order=2)

# 그래프 출력
sns.lineplot(data_upsampled)
plt.title('Hourly Resampled Exchange Rate (Interpolated)')
# Out:
# <ipython-input-86-2878751a2666>:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data_upsampled = data['USD'].resample('H').mean()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-2878751a2666> in <cell line: 2>()
#       1 # 'USD' 속성에 대해 업샘플링 (시간 단위) 및 'polynomial' (다항식 보간법) 적용 (order=2)
# ----> 2 data_upsampled = data['USD'].resample('H').mean()
#       3 data_upsampled = data_upsampled.interpolate(method='polynomial', order=2)
#       4
#       5 # 그래프 출력
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9769             convention = "start"
#    9770
# -> 9771         return get_resampler(
#    9772             cast("Series | DataFrame", self),
#    9773             freq=rule,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    2048     """
#    2049     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
# -> 2050     return tg._get_resampler(obj, kind=kind)
#    2051
#    2052
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    2270             )
#    2271
# -> 2272         raise TypeError(
#    2273             "Only valid with DatetimeIndex, "
#    2274             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'

# %%
# 이 셀을 실행하지 마시오.

# %% [markdown]
# ####
